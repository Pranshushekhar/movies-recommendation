# %%
import numpy as np
import pandas as pd
import networkx as nx
import nxviz as nv
import matplotlib.pyplot as plt

# %%
K = nx.Graph()
K.add_node(1)
K.add_node(2)
K.add_node(3)
K.add_node(4)
K.add_node(5)
K.add_node(6)
K.add_node(7)
K.add_node(8)

K.add_edge(1,2)
K.add_edge(2,3)
K.add_edge(1,4)
K.add_edge()

# c = nv.CircosPlot(K)
# c.draw()
# plt.show()

# %%
def recommendation(T, x):
    recos = {}
    for neigh in list(T.neighbors(x)):
        for possible in list(T.neighbors(neigh)):
            if possible not in list(T.neighbors(x)) and possible!=x:
                recos[possible] = 1
    return recos

# %%
recommendation(M,2)
# Out:
# {0: 1, 4: 1}

# %%
M = nx.path_graph(10)
c = nv.CircosPlot(M)
c.draw()
plt.show()
